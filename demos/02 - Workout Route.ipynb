# %%
import sys
sys.path.append("../")

from watchlib.data_handler import DataLoader
from watchlib.animation import WorkoutAnimation

# %%
dl = DataLoader("/Users/macbookpro/Documents/Code/watchlib/data/apple_health_export")

# %%
routes = dl.load_cached_routes()
route = routes["route_2020-04-04_6.37pm.gpx"]

# %%
wa = WorkoutAnimation(route)
ani = wa.animate()
ani.save("/Users/macbookpro/Desktop/animation.mp4", dpi=300, fps=50)
