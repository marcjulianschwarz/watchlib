# %%
import sys
sys.path.append("../")

from data_handler import DataLoader
from workout import workout_three_d

# %%
dl = DataLoader("/Users/macbookpro/Documents/Code/apple-health-analyser/data/apple_health_export")

# %%
routes = dl.load_workout_routes()
# Out:
# Loading 370 workout routes.

# %%
# %matplotlib widget
route = dl.read_workout_route(routes[369])
workout_three_d(route, resolution=0.2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
