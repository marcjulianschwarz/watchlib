# %%
import sys
sys.path.append("../")

from watchlib.data_handler import CacheHandler
from watchlib.animation import WorkoutAnimation

# %%
path = "path/to/your/apple_health_export"

# %%
ch = CacheHandler(path)

# %%
routes = ch.load_cached_routes()
route = routes[3]

# %%
wa = WorkoutAnimation(route)
wa.set_color_on("speed")
wa.set_fig_size((10, 10))
ani = wa.animate()
ani.save("path/to/animation.mp4", dpi=300, fps=50)
