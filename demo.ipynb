# %%
import matplotlib.pyplot as plt
import numpy as np

from data_handler import DataLoader

d = DataLoader("data/apple_health_export")
data = d.get_ecgs()

# %%
meta_data, ecg_data = d.read_ecg(data[0])

# %%
plt.scatter(x=np.linspace(0, 1, 3000), y=ecg_data["name"][:3000], s=3)
